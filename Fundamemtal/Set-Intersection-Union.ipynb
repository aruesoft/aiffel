# %%
# !pip install matplotlib-venn
# Out:
# Collecting matplotlib-venn
#   Using cached matplotlib_venn-0.11.9-py3-none-any.whl
# Requirement already satisfied: matplotlib in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib-venn) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/craigpark/miniconda/envs/tensorflow/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-0.11.9

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn3, venn3_circles

# %%
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 103            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 77            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(0.8) 

v.get_patch_by_id('10').set_color('w') 
v.get_patch_by_id('01').set_color('w') 
v.get_patch_by_id('11').set_color('yellow') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("white")
plt.gca().set_axis_on()

# %%
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(0.8) 

v.get_patch_by_id('10').set_color('lightgreen') 
v.get_patch_by_id('01').set_color('lightblue') 
v.get_patch_by_id('11').set_color('darkblue') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("white")
plt.gca().set_axis_on()

# %%
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(0.8) 

v.get_patch_by_id('10').set_color('lightgreen') 
v.get_patch_by_id('01').set_color('white') 
v.get_patch_by_id('11').set_color('white') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("white")
plt.gca().set_axis_on()

# %%
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(1.0) 
v.get_patch_by_id('01').set_alpha(1.0) 
v.get_patch_by_id('11').set_alpha(1.0) 

v.get_patch_by_id('10').set_color('skyblue') 
v.get_patch_by_id('01').set_color('white') 
v.get_patch_by_id('11').set_color('white') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("skyblue")
plt.gca().set_axis_on()

# %%
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13             # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8               # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B}, set_labels = ('Set A', 'Set B'))
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, 0), linestyle='solid')

v.get_patch_by_id('10').set_alpha(0.5)
v.get_patch_by_id('10').set_color('r')
v.get_patch_by_id('01').set_alpha(0.5)
v.get_patch_by_id('01').set_color('gray')
v.get_label_by_id('10').set_text('')
v.get_label_by_id('01').set_text('')
v.get_label_by_id('A').set_text('A')
v.get_label_by_id('B').set_text('B')

plt.gca().set_axis_on()
