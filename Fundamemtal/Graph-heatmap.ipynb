# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights['date'] = pd.to_datetime(flights['year'].astype(str)+'-'+flights['month'].astype(str))

# %%
pivot = flights.pivot(index='year',columns='month',values='passengers')
pivot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# **Seaborn.Heatmap**
#
# seaborn.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)

# %% [markdown]
# ----
# - data: 2차원 배열 형태의 데이터. 예시로 DataFrame, ndarray, list 등이 올 수 있습니다.
# - cmap: heatmap의 색상을 결정하는 colormap. matplotlib 라이브러리의 colormap을 사용할 수 있습니다.
# - center: colormap의 중심 값을 설정합니다.
# - annot: heatmap에 숫자를 출력할지 여부를 결정합니다.
# - linewidths: heatmap 내의 각 셀 경계선의 두께를 설정합니다.
# - linecolor: heatmap 내의 각 셀 경계선의 색상을 설정합니다.
# - xticklabels, yticklabels: heatmap x축, y축 레이블을 설정합니다.
#
# -----
#
# Parameters:
# datarectangular dataset
# 2D dataset that can be coerced into an ndarray. If a Pandas DataFrame is provided, the index/column information will be used to label the columns and rows.
#
# vmin, vmax : floats, optional
# Values to anchor the colormap, otherwise they are inferred from the data and other keyword arguments.
#
# cmap : matplotlib colormap name or object, or list of colors, optional
# The mapping from data values to color space. If not provided, the default will depend on whether center is set.
#
# center : float, optional
# The value at which to center the colormap when plotting divergent data. Using this parameter will change the default cmap if none is specified.
#
# robust : bool, optional
# If True and vmin or vmax are absent, the colormap range is computed with robust quantiles instead of the extreme values.
#
# annot : bool or rectangular dataset, optional
# If True, write the data value in each cell. If an array-like with the same shape as data, then use this to annotate the heatmap instead of the data. Note that DataFrames will match on position, not index.
#
# fmt : str, optional
# String formatting code to use when adding annotations.
#
# annot_kws : dict of key, value mappings, optional
# Keyword arguments for matplotlib.axes.Axes.text() when annot is True.
#
# linewidths : float, optional
# Width of the lines that will divide each cell.
#
# linecolor ; color, optional
# Color of the lines that will divide each cell.
#
# cbar : bool, optional
# Whether to draw a colorbar.
#
# cbar_kws : dict of key, value mappings, optional
# Keyword arguments for matplotlib.figure.Figure.colorbar().
#
# cbar_ax : matplotlib Axes, optional
# Axes in which to draw the colorbar, otherwise take space from the main Axes.
#
# square : bool, optional
# If True, set the Axes aspect to “equal” so each cell will be square-shaped.
#
# xticklabels, yticklabels : “auto”, bool, list-like, or int, optional
# If True, plot the column names of the dataframe. If False, don’t plot the column names. If list-like, plot these alternate labels as the xticklabels. If an integer, use the column names but plot only every n label. If “auto”, try to densely plot non-overlapping labels.
#
# mask : bool array or DataFrame, optional
# If passed, data will not be shown in cells where mask is True. Cells with missing values are automatically masked.
#
# ax : matplotlib Axes, optional
# Axes in which to draw the plot, otherwise use the currently-active Axes.
#
# kwarg : sother keyword arguments
# All other keyword arguments are passed to matplotlib.axes.Axes.pcolormesh().

# %%
sns.heatmap(pivot, linewidths=.2, annot=True, fmt="d",cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# **vmin , vmax**
#
#
# vmin과 vmax는 seaborn 라이브러리의 heatmap() 함수에서 사용되는 파라미터 중 하나로, heatmap에서 각 셀의 색상을 결정하는 데 사용됩니다.
#
# vmin은 colormap에서 가장 낮은 값을 나타내며, vmax는 colormap에서 가장 높은 값을 나타냅니다. vmin과 vmax는 heatmap을 그리기 전에 데이터의 범위를 먼저 설정하는 데 사용됩니다. 예를 들어, 데이터가 0에서 1사이의 값을 가지고 있을 때 vmin과 vmax를 각각 0과 1로 설정하면 colormap이 0에서 1사이의 값에 대해 적절하게 적용됩니다.
#
#
# 아래는 seaborn 라이브러리의 heatmap() 함수에서 vmin과 vmax 파라미터를 사용한 예시 코드입니다.

# %%
# 예시 데이터 생성
data = np.random.randn(10, 10)

# heatmap 그리기
sns.heatmap(data, vmin=0, vmax=1)

# 그래프 타이틀 설정
plt.title('Heatmap Example')

# x축, y축 레이블 설정
plt.xlabel('X Label')
plt.ylabel('Y Label')

# 그래프 출력
plt.show()

# %% [markdown]
# **cmap**
#
# - viridis: 녹색과 노란색 계열의 색상 맵
# - plasma: 핑크색과 보라색 계열의 색상 맵
# - magma: 검은색과 보라색 계열의 색상 맵
# - inferno: 주황색과 검은색 계열의 색상 맵
# - coolwarm: 파란색-빨간색 계열의 색상 맵
# - seismic: 파란색-빨간색 계열의 색상 맵. coolwarm보다 더 강렬한 색상을 가지고 있음

# %%
sns.heatmap(data,cmap='viridis',vmin=-1,vmax=1,alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data,cmap='Blues',vmin=-1,vmax=1,alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.cm as cm

cm.datad.keys()
# Out:
# dict_keys(['Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c'])
